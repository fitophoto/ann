# %%
#import библиотек для нейросети

import numpy as np
from sklearn.model_selection import train_test_split
import torch
import random
from torch import nn
from torchvision import models, transforms as T
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
#нейросеть - построение

class MyDataset(Dataset):
    def __init__(self, x, y, transform):
        self.transform = transform
        self.x = x
        #self.y = np.block([[1 - y], [y]]).T
        self.y = y.reshape((y.shape[0], 1))
    
    def __getitem__(self, idx):
        x_transform = self.transform(self.x[idx])
        return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
    
    def __len__(self):
        return self.x.shape[0]

def seed_all(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

def plot_losses(losses_train, losses_test):
    clear_output()
    plt.plot(range(1, len(losses_train) + 1), losses_train, label='train')
    plt.plot(range(1, len(losses_test) + 1), losses_test, label='test')
    plt.title('изменение качества при обучении', fontsize=14)
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend()
    plt.show()

def split_tests(ill, healthy):
    X = np.array(ill + healthy, dtype=object)
    y = np.array([0] * len(ill) + [1] * len(healthy))
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
    return X_train, X_test, y_train, y_test

def build_cnn(X_train, X_test, y_train, y_test):
    seed_all(0)

    BATCH_SIZE = 10

    transform = T.Compose([
                       T.Resize(256),
                       T.CenterCrop(224),
                       T.ToTensor(),
                       T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                       ])

    train_dataset = MyDataset(X_train, y_train, transform)
    test_dataset = MyDataset(X_test, y_test, transform)

    train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
    test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

    device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
    model = models.alexnet(pretrained=True)
    model.classifier[6] = nn.Sequential(
        nn.Linear(in_features=4096, out_features=1, bias=True),
        nn.Sigmoid()
      )
    model = model.to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5, weight_decay=1e-5)
    criterion = nn.BCELoss()
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99999)
    plt.rcParams['figure.figsize'] = (12, 9)
    
    NUM_EPOCHS = 30
    losses_train, losses_test = [], []

    for epoch in range(1, NUM_EPOCHS + 1):
        running_loss_train, running_loss_test = 0.0, 0.0
        model.train()
        for x, y in tqdm(train_dataloader):
        
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()
            scheduler.step()

            running_loss_train += loss.item() * y.shape[0]
    
        losses_train += [running_loss_train / len(train_dataset)]

        model.eval()
        for x, y in tqdm(test_dataloader):
            with torch.no_grad():
            
                x = x.to(device)
                y = y.to(device)

                logits = model(x)

                loss = criterion(logits, y)
                running_loss_test += loss.item() * y.shape[0]
    
        losses_test += [running_loss_test / len(test_dataset)]
    
    return losses_train, losses_test

# %%
#import библиотек для изображений

import os

from PIL import Image
import pyheif

# %%
#чтение исходных изображений

data_ill = []
data_healthy = []


for folder in os.listdir(path="ill"):
    for file in os.listdir(path="ill/" + folder + "/"):
        try:
            heif_file = pyheif.read("ill/" + folder + "/" + file)
            image = Image.frombytes(
                heif_file.mode, 
                heif_file.size, 
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride,
                ).resize((100, 150))
            data_ill.append(image)
        except:
            pass

for folder in os.listdir(path="healthy"):
    for file in os.listdir(path="healthy/" + folder + "/"):
        try:
            heif_file = pyheif.read("healthy/" + folder + "/" + file)
            image = Image.frombytes(
                heif_file.mode, 
                heif_file.size, 
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride,
                ).resize((100, 150))
            data_healthy.append(image)
        except:
            pass

print(len(data_ill), " ", len(data_healthy))
# Out:
# 203   157

# %%
#демонстрация оригинальной картинки

data_ill[0]
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7FF4C04CE1C0>

# %%
#разделение на тренировочную и тестовую выборки

X_train, X_test, y_train, y_test = split_tests(data_ill, data_healthy)
# Out:
# /tmp/ipykernel_249616/1005599837.py:40: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   X = np.array(ill + healthy, dtype=object)

# %% [markdown]
# # Эксперимент 0

# %% [markdown]
# Обучение нейросети на оригинальных изображениях, без фильтров

# %%
#обучаем нейросеть

result_train_0, result_test_0 = build_cnn(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

print("train :", result_train_0[9], result_train_0[19], result_train_0[29])
print("test :", result_test_0[9], result_test_0[19], result_test_0[29])
# Out:
# train : 0.00763559430035659 0.000894176078738248 0.0004296261249692179
# test : 0.02471140456489391 0.011813570267501442 0.008212536915177933

# %% [markdown]
# # Эксперимент 1

# %% [markdown]
# Хотим повысить контрастность каждого пикселя на основе всего изображения:
#
# 1. Считаем средние значения \\( R, G, B \\) по всем пикселям изображения.
#
# 2. Далее заменяем для каждого пикселя
#
# $$ r = r + (r - R) * coef $$
# $$ g = g + (g - G) * coef $$
# $$ b = b + (b - B) * coef $$
#
# 3. Коэффициент \\( coef \\) перебираем в множестве \\( \{0.5, 1\} \\)

# %%
#функция, повышающая контрастность на основе всего изображения

def contrast_pixel(px, mean, coef):
    res = [0, 0, 0]
    for i in range(3):
        res[i] = int(px[i] + (px[i] - mean[i]) * coef)
        res[i] = max(0, min(255, res[i]))
    return (res[0], res[1], res[2])

def more_contrast(image, coef):
    w = image.width
    h = image.height
    data = np.asarray(image)
    mean = [0, 0, 0]
    for i in range(h):
        for j in range(w):
            for k in range(3):
                mean[k] += data[i][j][k]
    mean[0] /= w * h
    mean[1] /= w * h
    mean[2] /= w * h
    data2 = []
    for i in range(h):
        for j in range(w):
            data2.append(contrast_pixel(data[i][j], mean, coef))
    img2 = Image.new("RGB", (image.size))
    img2.putdata(data2)
    return img2

# %%
#пример работы функции на оригинальном изображении

more_contrast(data_ill[0], 1)
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7F078611D8E0>

# %%
#применяем фильтр и обучаем нейросеть

coefs_1 = [0.5, 1]
result_train_1 = []
result_test_1 = []

for coef in coefs_1:
    temp_X_train = np.array([more_contrast(img, coef) for img in X_train])
    print(type(temp_X_train))
    temp_train, temp_test = build_cnn(temp_X_train, X_test, y_train, y_test)
    result_train_1.append(temp_train)
    result_test_1.append(temp_test)
# Out:
# /tmp/ipykernel_7793/743989426.py:8: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([more_contrast(img, coef) for img in X_train])
# /tmp/ipykernel_7793/743989426.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([more_contrast(img, coef) for img in X_train])
# <class 'numpy.ndarray'>
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

for i in range(len(result_train_1)):
    print("train (coef = ", coefs_1[i], ") : ", sep="", end="")
    print(result_train_1[i][9], result_train_1[i][19], result_train_1[i][29])

    print("test (coef = ", coefs_1[i], ") : ", sep="", end="")
    print(result_test_1[i][9], result_test_1[i][19], result_test_1[i][29])
    print()
# Out:
# train (coef = 0.5) : 0.008957594387336738 0.0009746531666476383 0.000403193563821939
# test (coef = 0.5) : 0.032318312829981245 0.013787459853726128 0.010417861659435503
#
# train (coef = 1) : 0.010989406879094464 0.0009589177781082173 0.0003019577447115875
# test (coef = 1) : 0.06375504988763067 0.03977753992916809 0.04648454626375395

# %% [markdown]
# # Эксперимент 2

# %% [markdown]
# Хотим повысить контрастность зеленой составляющей каждого пикселя на основе всего изображения:
#
# 1. Считаем среднее значение \\( G \\) по всем пикселям изображения.
#
# 2. Далее заменяем для каждого пикселя
#
# $$ g = g + (g - G) * coef $$
#
# 3. Коэффициент \\( coef \\) перебираем в множестве \\( \{0.5, 1\} \\)

# %%
#функция, повышающая контрастность зеленого на основе всего изображения

def green_contrast_pixel(px, mean, coef):
    new_g = int(px[1] + (px[1] - mean) * coef)
    return (px[0], new_g, px[2])

def more_green_contrast(image, coef):
    w = image.width
    h = image.height
    data = np.asarray(image)
    mean = 0
    for i in range(h):
        for j in range(w):
            mean += data[i][j][1]
    mean /= w * h
    data2 = []
    for i in range(h):
        for j in range(w):
            data2.append(green_contrast_pixel(data[i][j], mean, coef))
    img2 = Image.new("RGB", (image.size))
    img2.putdata(data2)
    return img2

# %%
#пример работы функции на оригинальном изображении

more_green_contrast(data_ill[0], 1)
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7F071353BF70>

# %%
#применяем фильтр и обучаем нейросеть

coefs_2 = [0.5, 1]
result_train_2 = []
result_test_2 = []

for coef in coefs_2:
    temp_X_train = np.array([more_green_contrast(img, coef) for img in X_train])
    temp_train, temp_test = build_cnn(temp_X_train, X_test, y_train, y_test)
    result_train_2.append(temp_train)
    result_test_2.append(temp_test)
# Out:
# /tmp/ipykernel_7793/2943650266.py:8: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([more_green_contrast(img, coef) for img in X_train])
# /tmp/ipykernel_7793/2943650266.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([more_green_contrast(img, coef) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

for i in range(len(result_train_2)):
    print("train (coef = ", coefs_2[i], ") : ", sep="", end="")
    print(result_train_2[i][9], result_train_2[i][19], result_train_2[i][29])

    print("test (coef = ", coefs_2[i], ") : ", sep="", end="")
    print(result_test_2[i][9], result_test_2[i][19], result_test_2[i][29])
    print()
# Out:
# train (coef = 0.5) : 0.013596281357523467 0.0015037021480060907 0.00056793239599318
# test (coef = 0.5) : 0.07585509111069971 0.053650451410147876 0.054335474554035396
#
# train (coef = 1) : 0.014798326435050479 0.0018894396489486098 0.000496192327571205
# test (coef = 1) : 0.11985799897876051 0.08242800961145097 0.07656420542237659

# %% [markdown]
# # Эксперимент 3

# %% [markdown]
# Хотим повысить контрастность зеленой составляющей пикселей, в которых она "главная" и нет.
#
# А именно, ко всем пикселям, для которых верно \\( g \leq max(r, b) \\), применяем \\( g = 0 \\)

# %%
#функция-фильтр

def green_check(r, g, b):
    if (g > r and g > b):
        return (r, g, b)
    return (r, 0, b)

def less_green(img):
    now = list(img.getdata())
    now2 = [green_check(px[0], px[1], px[2]) for px in now]
    img_ans = Image.new("RGB", img.size)
    img_ans.putdata(now2)
    return img_ans

# %%
#пример работы функции на оригинальном изображении

less_green(data_ill[0])
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7F071354D730>

# %%
#применяем фильтр и обучаем нейросеть

temp_X_train = np.array([less_green(img) for img in X_train])

result_train_3, result_test_3 = build_cnn(temp_X_train, X_test, y_train, y_test)
# Out:
# /tmp/ipykernel_7793/4124170114.py:3: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([less_green(img) for img in X_train])
# /tmp/ipykernel_7793/4124170114.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([less_green(img) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

print("train :", result_train_3[9], result_train_3[19], result_train_3[29])
print("test :", result_test_3[9], result_test_3[19], result_test_3[29])
# Out:
# train : 0.008903591451666283 0.0011784259886890478 0.0003134391832915113
# test : 1.090672383705775 1.51458078622818 1.6609372761514452

# %% [markdown]
# # Эксперимент 4

# %% [markdown]
# Хочется перевести в цветовую модель HSV. Переводим каждый пиксель из \\( R, G, B \\) по формулам с википедии:
#
# \\( H = \\)
#   - \\( 0 \\), если \\(MAX = MIN\\)
#   - \\( 60\cdot \frac{G - B}{MAX - MIN} \\), если \\( MAX = R, G \leq B \\)
#   - \\( 60\cdot \frac{G - B}{MAX - MIN} + 360 \\), если \\( MAX = R, G < B \\)
#   - \\( 60\cdot \frac{B - R}{MAX - MIN} + 120 \\), если \\( MAX = G \\)
#   - \\( 60\cdot \frac{R - G}{MAX - MIN} + 240 \\), если \\( MAX = B \\)
#
# \\( S = \\)
#   - \\( 0 \\), если \\( MAX = 0 \\)
#   - \\( 1 - \frac{MIN}{MAX} \\), иначе
#
# \\( V = MAX \\)
#
# Т.к. \\(H\\) - число от \\(0\\) до \\(360\\), \\(S, V\\) - от \\(0\\) до \\(1\\), нормируем все числа в целые \[0; 255\], чтобы пользоваться RGB-системой и тем же построением сети

# %%
#перевод RGB в HSV

def rgb_to_hsv(px):
    r = px[0] / 255
    g = px[1] / 255
    b = px[2] / 255
    
    mx = max(r, g, b)
    mn = min(r, g, b)
    
    h, s, v = 0, 0, mx
    if mx != mn and mx == r and g >= b:
        h = 60 * (g - b) / (mx - mn)
    elif mx != mn and mx == r and g < b:
        h = 60 * (g - b) / (mx - mn) + 360
    elif mx != mn and mx == g:
        h = 60 * (b - r) / (mx - mn) + 120
    elif mx != mn and mx == b:
        h = 60 * (r - g) / (mx - mn) + 240
    
    if mx != 0:
        s = 1 - mn / mx

    return (h, s, v)

#нормировка HSV в RGB для удобства пользования изображениями

def converted_hsv(px):
    h, s, v = rgb_to_hsv(px)

    r = int(h / 360 * 255)
    g = int(s * 255)
    b = int(v * 255)
    return (r, g, b)

#перевод картинки в HSV

def image_to_hsv(img):
    w = img.width
    h = img.height
    img2 = img.copy()
    for i in range(w):
        for j in range(h):
            img2.putpixel((i, j), converted_hsv(img.getpixel((i, j))))
    return img2

# %%
#пример работы функции на оригинальном изображении

image_to_hsv(data_ill[0])
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7FF49AFE95E0>

# %%
#применяем фильтр и обучаем нейросеть

temp_X_train = np.array([image_to_hsv(img) for img in X_train])

result_train_4, result_test_4 = build_cnn(temp_X_train, X_test, y_train, y_test)
# Out:
# /tmp/ipykernel_7793/1464459407.py:3: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([image_to_hsv(img) for img in X_train])
# /tmp/ipykernel_7793/1464459407.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([image_to_hsv(img) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

print("train :", result_train_4[9], result_train_4[19], result_train_4[29])
print("test :", result_test_4[9], result_test_4[19], result_test_4[29])
# Out:
# train : 0.007806576888671973 0.0008782307623833832 0.00015602049614716197
# test : 1.7268252107832167 2.8768476910061307 3.5747296280331082

# %% [markdown]
# # Эксперимент 5

# %% [markdown]
# Хочется перевести в цветовую модель HSV. Переводим каждый пиксель из \\( R, G, B \\) по формулам с википедии, предварительно нормируя R, G, B в \[0; 1\]:
#
# \\( H = \\)
#   - \\( 0 \\), если \\(MAX = MIN\\)
#   - \\( 60\cdot \frac{G - B}{MAX - MIN} \\), если \\( MAX = R, G \geq B \\)
#   - \\( 60\cdot \frac{G - B}{MAX - MIN} + 360 \\), если \\( MAX = R, G < B \\)
#   - \\( 60\cdot \frac{B - R}{MAX - MIN} + 120 \\), если \\( MAX = G \\)
#   - \\( 60\cdot \frac{R - G}{MAX - MIN} + 240 \\), если \\( MAX = B \\)
#
# \\(L = \frac{MAX + MIN}{2} \\)
#
# \\( S = \\)
#   - \\( 0 \\), если \\( L = 0 \\) или \\( MAX = 0 \\)
#   - \\( \frac{MAX - MIN}{MAX + MIN} \\), если \\( 0 < L \leq \frac 12 \\)
#   - \\( \frac{MAX - MIN}{2 - (MAX + MIN)} \\), если \\( \frac{1}{2} < L \leq 1 \\)
#
# Т.к. \\(H\\) - число от \\(0\\) до \\(360\\), \\(S, L\\) - от \\(0\\) до \\(1\\), нормируем все числа в целые \[0; 255\], чтобы пользоваться RGB-системой и тем же построением сети

# %%
#перевод из RGB в HSL

def rgb_to_hsl(px):
    r = px[0] / 255
    g = px[1] / 255
    b = px[2] / 255
    
    mx = max(r, g, b)
    mn = min(r, g, b)
    
    h, s, l = 0, 0, 0
    if mx != mn and mx == r and g >= b:
        h = 60 * (g - b) / (mx - mn)
    elif mx != mn and mx == r and g < b:
        h = 60 * (g - b) / (mx - mn) + 360
    elif mx != mn and mx == g:
        h = 60 * (b - r) / (mx - mn) + 120
    elif mx != mn and mx == b:
        h = 60 * (r - g) / (mx - mn) + 240
    
    if mx == mn:
        s = 0
    else:
        s = (mx - mn) / abs(1 - abs(1 - (mx + mn)))
    l = (mx + mn) / 2

    return (h, s, l)

#конвертация изображения в HSL

def converted_hsl(px):
    h, s, l = rgb_to_hsl(px)
    r = int(h / 360 * 255)
    g = int(s * 255)
    b = int(l * 255)
    return (r, g, b)

def image_to_hsl(img):
    w = img.width
    h = img.height
    img2 = img.copy()
    for i in range(w):
        for j in range(h):
            img2.putpixel((i, j), converted_hsl(img.getpixel((i, j))))
    return img2

# %%
#пример работы функции на оригинальном изображении

image_to_hsl(data_ill[0])
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7F06E763A490>

# %%
#применяем фильтр и обучаем нейросеть

temp_X_train = np.array([image_to_hsl(img) for img in X_train])

result_train_5, result_test_5 = build_cnn(temp_X_train, X_test, y_train, y_test)
# Out:
# /tmp/ipykernel_7793/3191681746.py:3: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([image_to_hsl(img) for img in X_train])
# /tmp/ipykernel_7793/3191681746.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([image_to_hsl(img) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

print("train :", result_train_5[9], result_train_5[19], result_train_5[29])
print("test :", result_test_5[9], result_test_5[19], result_test_5[29])
# Out:
# train : 0.007516270299674943 0.0008520816899598921 0.00017979522032907913
# test : 1.126880665620168 1.8467627300156488 2.302873518731859

# %% [markdown]
# # Эксперимент 6

# %% [markdown]
# Хочется выделять куски изображения зеленого цвета. По HSV можно измерить близость цвета к зеленому как близость числа H пикселя к 120. У недостаточно зеленых кусков будем понижать яркость.
#
# Очень светлые (с маленьким \\(V\\)) пиксели тоже вряд ли можно считать зелеными, поэтому добавим отсечение по \\(V\\) тоже. То есть для каждого пикселя:
#
# 1. Переведем в HSV модель
# 2. Если \\( |H - 120| \leq dist \\) и \\( V \geq light \\), то оставим его как есть
# 3. Иначе умножим \\(R, G, B\\) на \\( coef \\)

# %%
#затемняем цвета, далекие от зеленого в системе HSV

def green_based_rgb(px, coef, dist, light):
    h, s, v = rgb_to_hsv(px)
    if 120 - dist <= h and h <= 120 + dist and s > light:
        return (px[0], px[1], px[2])
    return (int(px[0] // coef), int(px[1] // coef), int(px[2] // coef))

def to_green_based_hsv(img, coef, dist, light):
    w = img.width
    h = img.height
    img2 = img.copy()
    for i in range(w):
        for j in range(h):
            img2.putpixel((i, j), green_based_rgb(img.getpixel((i, j)), coef, dist, light))
    return img2

# %%
#пример работы функции на оригинальном изображении

to_green_based_hsv(data_ill[0], 10, 80, 0.25)
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7FF42DFF7190>

# %% [markdown]
# Перебираем параметры \\( light \\) с фиксированными \\( coef = 2, dist = 80 \\)

# %%
#применяем фильтр и обучаем нейросеть

lights_6 = [0, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45]
light_result_train_6 = []
light_result_test_6 = []

for lig in lights_6:
    temp_X_train = np.array([to_green_based_hsv(img, 2, 80, lig) for img in X_train])
    
    temp_train, temp_test = build_cnn(temp_X_train, X_test, y_train, y_test)
    light_result_train_6.append(temp_train)
    light_result_test_6.append(temp_test)
# Out:
# /tmp/ipykernel_7793/3810427104.py:8: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([to_green_based_hsv(img, 2, 80, lig) for img in X_train])
# /tmp/ipykernel_7793/3810427104.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([to_green_based_hsv(img, 2, 80, lig) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# ...
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

for i in range(len(light_result_train_6)):
    print("train (light = ", lights_6[i], ") : ", sep="", end="")
    print(light_result_train_6[i][9], light_result_train_6[i][19], light_result_train_6[i][29])

    print("test (light = ", lights_6[i], ") : ", sep="", end="")
    print(light_result_test_6[i][9], light_result_test_6[i][19], light_result_test_6[i][29])
    print()
# Out:
# train (light = 0) : 0.010487141570559255 0.0013262631430363938 0.0002525697539197238
# test (light = 0) : 0.06630897739281257 0.043402361761157714 0.03322251306639777
#
# train (light = 0.1) : 0.012169604232810714 0.0020342956526696477 0.0003880123179071773
# test (light = 0.1) : 0.09150954532540506 0.06956018737077506 0.06474130732466518
#
# train (light = 0.15) : 0.011080260138475784 0.0015100159841865577 0.00041382655749826143
# test (light = 0.15) : 0.08185334889114732 0.06143373682991498 0.0476969315786846
#
# train (light = 0.2) : 0.00997358623943809 0.0009990728188616533 0.0004993440008412883
# test (light = 0.2) : 0.04523139384885629 0.03136019969436651 0.023295853772045422
#
# train (light = 0.25) : 0.009598035119577415 0.0012933043555541964 0.00035962717002904456
# test (light = 0.25) : 0.0654335060260362 0.04935691413185042 0.04123206926871919
#
# train (light = 0.3) : 0.009515678307420953 0.0013505235606485425 0.0004309755612565722
# test (light = 0.3) : 0.07749477476398978 0.07175250764703378 0.05994932113551638
#
# train (light = 0.35) : 0.008518451969225512 0.0011780944079402144 0.0005540729210527692
# test (light = 0.35) : 0.07171162864607242 0.06325717071821499 0.05771247386938841
#
# train (light = 0.4) : 0.008055477704921807 0.0008165952000396188 0.0004207913919311034
# test (light = 0.4) : 0.07870046602975991 0.072962159556078 0.0748598721919633
#
# train (light = 0.45) : 0.010133477406472795 0.0009211206135525437 0.000570826598589149
# test (light = 0.45) : 0.06725172971427026 0.058691886808244616 0.05907655293736348

# %% [markdown]
# Перебираем параметры \\( coef \\) с фиксированными \\( light = 0.3, dist = 80 \\)

# %%
#применяем фильтр и обучаем нейросеть

coefs_6 = [1.5, 2, 2.5]
coef_result_train_6 = []
coef_result_test_6 = []

for coef in coefs_6:
    temp_X_train = np.array([to_green_based_hsv(img, coef, 80, 0.2) for img in X_train])
    
    temp_train, temp_test = build_cnn(temp_X_train, X_test, y_train, y_test)
    coef_result_train_6.append(temp_train)
    coef_result_test_6.append(temp_test)
# Out:
# /tmp/ipykernel_7793/3723841655.py:8: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([to_green_based_hsv(img, coef, 80, 0.2) for img in X_train])
# /tmp/ipykernel_7793/3723841655.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([to_green_based_hsv(img, coef, 80, 0.2) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# ...
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_7793/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

for i in range(len(coef_result_train_6)):
    print("train (coef = ", coefs_6[i], ") : ", sep="", end="")
    print(coef_result_train_6[i][9], coef_result_train_6[i][19], coef_result_train_6[i][29])

    print("test (coef = ", coefs_6[i], ") : ", sep="", end="")
    print(coef_result_test_6[i][9], coef_result_test_6[i][19], coef_result_test_6[i][29])
    print()
# Out:
# train (coef = 1.5) : 0.008433636782380441 0.0009668708234029408 0.0004456711453207794
# test (coef = 1.5) : 0.028149812133051455 0.015932321778058797 0.01334609341008925
#
# train (coef = 2) : 0.00997358623943809 0.0009990728188616533 0.0004993440008412883
# test (coef = 2) : 0.04523139384885629 0.03136019969436651 0.023295853772045422
#
# train (coef = 2.5) : 0.011898922639105606 0.0012890878208930156 0.0004591381155613042
# test (coef = 2.5) : 0.07715843167776863 0.0639465793566261 0.051586111234630354

# %% [markdown]
# Перебираем параметры \\( dist \\) с фиксированными \\( light = 0.3, coef = 1.5 \\)

# %%
#применяем фильтр и обучаем нейросеть

dists_6 = [20, 30, 40, 50, 60, 70, 80, 90]
dist_result_train_6 = []
dist_result_test_6 = []

for dist in dists_6:
    temp_X_train = np.array([to_green_based_hsv(img, 1.5, dist, 0.2) for img in X_train])
    
    temp_train, temp_test = build_cnn(temp_X_train, X_test, y_train, y_test)
    dist_result_train_6.append(temp_train)
    dist_result_test_6.append(temp_test)
# Out:
# /tmp/ipykernel_249616/3431756028.py:8: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   temp_X_train = np.array([to_green_based_hsv(img, 1.5, dist, 0.2) for img in X_train])
# /tmp/ipykernel_249616/3431756028.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp_X_train = np.array([to_green_based_hsv(img, 1.5, dist, 0.2) for img in X_train])
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/27 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)
#   0%|          | 0/9 [00:00<?, ?it/s]
# /tmp/ipykernel_249616/1005599837.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x_transform, dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# %%
#выводим ошибку с шагом 10

for i in range(len(dist_result_train_6)):
    print("train (dist = ", dists_6[i], ") : ", sep="", end="")
    print(dist_result_train_6[i][9], dist_result_train_6[i][19], dist_result_train_6[i][29])

    print("test (dist = ", dists_6[i], ") : ", sep="", end="")
    print(dist_result_test_6[i][9], dist_result_test_6[i][19], dist_result_test_6[i][29])
    print()
# Out:
# train (dist = 20) : 0.006484702790018033 0.001035315855174472 0.0003357005209383917
# test (dist = 20) : 0.08992217155173421 0.12742689733083049 0.11206380244240993
#
# train (dist = 30) : 0.006352585332933813 0.0008076381065486068 0.0003209696480250083
# test (dist = 30) : 0.10051922593265772 0.12729684333316982 0.12131441443408322
#
# train (dist = 40) : 0.007747801557545447 0.000585381215421 0.00033023461037373636
# test (dist = 40) : 0.03352814793793692 0.020089525509522192 0.01895710987284676
#
# train (dist = 50) : 0.007268434761230041 0.0009220234838991288 0.00043611514795177046
# test (dist = 50) : 0.04714481617944936 0.020200826014236856 0.015010822089809354
#
# train (dist = 60) : 0.005985113352330195 0.0009675756367936696 0.000521986869662888
# test (dist = 60) : 0.035238445477767125 0.016400549950453244 0.011246131640493533
#
# train (dist = 70) : 0.007434912349304391 0.0008500119148703999 0.0004217164760457645
# test (dist = 70) : 0.0267983415008833 0.012659119768714946 0.009000830016399656
#
# train (dist = 80) : 0.008433636782380441 0.0009668708234029408 0.0004456711453207794
# test (dist = 80) : 0.028149812133051455 0.015932321778058797 0.01334609341008925
#
# train (dist = 90) : 0.009648391243967193 0.0012042438196389143 0.0005398851326727136
# test (dist = 90) : 0.03291692939173016 0.01845423978779258 0.015081981671553675
