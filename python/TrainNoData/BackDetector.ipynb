# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
import tqdm
import sys
import os

from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, auc, roc_curve
from tqdm.notebook import tqdm_notebook

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()
sns.set(font_scale=1.3)
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %%
dataset = torchvision.datasets.ImageFolder(root="C:/Users/Wxei/fitoBack/BackClassifier/")

split_ratio = 0.8

train_size = int(split_ratio * len(dataset))
test_size = len(dataset) - train_size
train_set, test_set = torch.utils.data.random_split(dataset, [train_size, test_size])

# %%
train_set.dataset.transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_set.dataset.transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
BATCH_SIZE = 128

train_loader = torch.utils.data.DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True,  num_workers=6)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=True,  num_workers=6)

cuda = torch.device('cuda')

# %%
model = nn.Sequential(
    nn.Conv2d(3, 6, 3),
    nn.ReLU(),
    nn.MaxPool2d(3),
    nn.Conv2d(6, 12, 3),
    nn.ReLU(),
    nn.MaxPool2d(3),
    nn.Conv2d(12, 24, 3),
    nn.ReLU(),
    nn.MaxPool2d(3),
    
    nn.Flatten(),
    nn.Dropout(),
    nn.Linear(4056, 128),
    nn.ReLU(),
    nn.Linear(128, 1),
    nn.Sigmoid()
).to(cuda)

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters())
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

n_epochs = 20

# %%
def train_epoch(model, train_loader, criterion, optimizer, device="cuda:0"):
    model.train()
    train_losses = []
    for imgs, true_labels in train_loader:
        out = model(imgs.to(device)).squeeze()
        true_labels = true_labels.float().to(device)
        loss = criterion(out, true_labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_losses.append(loss.item())
    
    sns.lineplot(x=range(len(train_losses)), y=train_losses)
    plt.xlabel('train step')
    plt.ylabel('train loss')
    plt.show()

# %%
def run_test(model, test_loader, device):
    model.eval()
    with torch.no_grad():
        out, labels = np.array([]), np.array([])
        for imgs, true_labels in test_loader:
            out = np.hstack((out, model(imgs.to(device)).squeeze().cpu()))
            labels = np.hstack((labels, true_labels.float()))
        print(out.shape)
        print(labels.shape)
        pred_labels = (out > 0.5).astype(int)
    return accuracy_score(labels, pred_labels)

# %%
for epoch in range(n_epochs):
    train_epoch(model, train_loader, criterion, optimizer, cuda)
    acc = run_test(model, test_loader, cuda)
    scheduler.step()
    print(f'accuracy: {acc}')
# Out:
# (1172,)
# (1172,)
# accuracy: 0.9965870307167235
# (1172,)
# (1172,)
# accuracy: 0.9991467576791809
# (1172,)
# (1172,)
# accuracy: 1.0
# (1172,)
# (1172,)
# accuracy: 0.9880546075085325
# (1172,)
# (1172,)
# accuracy: 0.9914675767918089
# (1172,)
# (1172,)
# accuracy: 0.9991467576791809
# (1172,)
# (1172,)
# accuracy: 1.0
# (1172,)
# (1172,)
# accuracy: 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 for epoch in range(n_epochs):
# ----> 2     train_epoch(model, train_loader, criterion, optimizer, cuda)
#       3     acc = run_test(model, test_loader, cuda)
#       4     scheduler.step()
#
# Input In [8], in train_epoch(model, train_loader, criterion, optimizer, device)
#       2 model.train()
#       3 train_losses = []
# ----> 4 for imgs, true_labels in train_loader:
#       5     out = model(imgs.to(device)).squeeze()
#       6     true_labels = true_labels.float().to(device)
#
# File ~\anaconda3\envs\fito\lib\site-packages\torch\utils\data\dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\envs\fito\lib\site-packages\torch\utils\data\dataloader.py:1207, in _MultiProcessingDataLoaderIter._next_data(self)
#    1204     return self._process_data(data)
#    1206 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1207 idx, data = self._get_data()
#    1208 self._tasks_outstanding -= 1
#    1209 if self._dataset_kind == _DatasetKind.Iterable:
#    1210     # Check for _IterableDatasetStopIteration
#
# File ~\anaconda3\envs\fito\lib\site-packages\torch\utils\data\dataloader.py:1173, in _MultiProcessingDataLoaderIter._get_data(self)
#    1169     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1170     # need to call `.task_done()` because we don't use `.join()`.
#    1171 else:
#    1172     while True:
# -> 1173         success, data = self._try_get_data()
#    1174         if success:
#    1175             return data
#
# File ~\anaconda3\envs\fito\lib\site-packages\torch\utils\data\dataloader.py:1011, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#     998 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#     999     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1000     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1008     # Returns a 2-tuple:
#    1009     #   (bool: whether successfully get data, any: data if successful else None)
#    1010     try:
# -> 1011         data = self._data_queue.get(timeout=timeout)
#    1012         return (True, data)
#    1013     except Exception as e:
#    1014         # At timeout and error, we manually check whether any worker has
#    1015         # failed. Note that this is the only mechanism for Windows to detect
#    1016         # worker failures.
#
# File ~\anaconda3\envs\fito\lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~\anaconda3\envs\fito\lib\multiprocessing\connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File ~\anaconda3\envs\fito\lib\multiprocessing\connection.py:335, in PipeConnection._poll(self, timeout)
#     332 if (self._got_empty_message or
#     333             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     334     return True
# --> 335 return bool(wait([self], timeout))
#
# File ~\anaconda3\envs\fito\lib\multiprocessing\connection.py:884, in wait(object_list, timeout)
#     881                 ready_objects.add(o)
#     882                 timeout = 0
# --> 884     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     885 finally:
#     886     # request that overlapped reads stop
#     887     for ov in ov_list:
#
# File ~\anaconda3\envs\fito\lib\multiprocessing\connection.py:816, in _exhaustive_wait(handles, timeout)
#     814 ready = []
#     815 while L:
# --> 816     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     817     if res == WAIT_TIMEOUT:
#     818         break
#
# KeyboardInterrupt:

# %%
def evaluation(model, test_loader, device):
    model.eval()
    for imgs, true_labels in test_loader:
        out = model(imgs.to(device)).squeeze()
        true_labels = true_labels.float().to(device)
    pred_labels = (out.detach().cpu().numpy() > 0.5).astype(int)
    true_labels = true_labels.detach().cpu().numpy()
    acc = accuracy_score(true_labels, pred_labels)
    pr = precision_score(true_labels, pred_labels)
    recall = recall_score(true_labels, pred_labels)
    print(f'accuracy: {acc}')
    print(f'precision: {pr}')
    print(f'recall: {recall}')
    
    fpr, tpr, thresholds = roc_curve(true_labels, pred_labels, pos_label=1)
    auc_score = auc(fpr, tpr)
    print(f'auc: {auc_score}')
    
    conf_matrix = confusion_matrix(true_labels, pred_labels)
    heatmap = sns.heatmap(conf_matrix, annot=True)
    heatmap.set(xlabel='Predicted label', ylabel='True label')
    plt.show()

# %%
evaluation(model, test_loader, cuda)
# Out:
# accuracy: 1.0
# precision: 1.0
# recall: 1.0
# auc: 1.0

# %%
path = "C:/Users/Wxei/fitoBack/savedModels/backDetector.pt"

# %%
torch.save(model, path)
